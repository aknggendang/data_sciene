# %% [markdown]
# # Import Module

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\bijin\AppData\Local\Temp\ipykernel_6136\1349762990.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Data Importing

# %%
anime_ds = pd.read_csv("anime.csv")

# %%
anime_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
anime_ds
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
anime_ds.head(10)
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6     11061                             Hunter x Hunter (2011)
# 7       820                               Ginga Eiyuu Densetsu
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9     15417                           Gintama&#039;: Enchousen
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# ...

# %%
anime_ds.sample(10)
# Out:
#        anime_id                                               name  \
# 6415       2163                          AIKa R-16: Virgin Mission
# 3063       3811                     Hoshi no Oujisama Petit Prince
# 11541      2861                        Seifuku Shojo The Animation
# 4857       9924  Shukufuku no Campanella: La Campanella Della B...
# 6528       3205                           Cream Lemon: Lemon Angel
# 180       18195                           Little Busters!: Refrain
# 9750      32773  Nintama Rantarou no Uchuu Daibouken with Cosmi...
# 6727       9627                               Kakko Kawaii Sengen!
# 6461      28815                     Bamboo Blade: CM Fanfu-Fufe-Fo
# 2000       1521                               Black Jack the Movie
#
#                                                    genre     type episodes  \
# 6415                               Action, Comedy, Ecchi      OVA        3
# 3063                                           Adventure       TV       39
# ...

# %% [markdown]
# # Data Indexing

# %%
anime_ds.index
# Out:
# RangeIndex(start=0, stop=12294, step=1)

# %%
anime_ds.set_index("type")
# Out:
#        anime_id                                               name  \
# type
# Movie     32281                                     Kimi no Na wa.
# TV         5114                   Fullmetal Alchemist: Brotherhood
# TV        28977                                           Gintama°
# TV         9253                                        Steins;Gate
# TV         9969                                      Gintama&#039;
# ...         ...                                                ...
# OVA        9316       Toushindai My Lover: Minami tai Mecha-Minami
# OVA        5543                                        Under World
# OVA        5621                     Violence Gekiga David no Hoshi
# OVA        6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# Movie     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre episodes  rating  \
# type
# ...

# %%
anime_ds.loc[20]
# Out:
# anime_id                               263
# name                        Hajime no Ippo
# genre       Comedy, Drama, Shounen, Sports
# type                                    TV
# episodes                                75
# rating                                8.83
# members                             157670
# Name: 20, dtype: object

# %%
anime_ds.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
anime_ds.loc[:,["name","type","genre"]]
# Out:
#                                                     name   type  \
# 0                                         Kimi no Na wa.  Movie
# 1                       Fullmetal Alchemist: Brotherhood     TV
# 2                                               Gintama°     TV
# 3                                            Steins;Gate     TV
# 4                                          Gintama&#039;     TV
# ...                                                  ...    ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami    OVA
# 12290                                        Under World    OVA
# 12291                     Violence Gekiga David no Hoshi    OVA
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...    OVA
# 12293                   Yasuji no Pornorama: Yacchimae!!  Movie
#
#                                                    genre
# 0                   Drama, Romance, School, Supernatural
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...
# ...

# %% [markdown]
# # Data Convert
